# %%
import regex as re
from cs336_basics.pretokenization_example import find_chunk_boundaries


input_path:str = "../data/TinyStoriesV2-GPT4-valid.txt"
vocab_size:int = 1024
special_tokens:list[str] = ["<|endoftext|>", "<|startoftext|>", ]

# 1.初始化词表
vocab:dict[int,bytes] = {i:bytes([i]) for i in range(256)}
merges:list[tuple[bytes, bytes]] = []
next_token_id = 256  
existing_bytes_token:set[bytes] = set(vocab.values())# 集合记录词表中已合并出的字节token和特殊token，用于高效索引
# 添加special tokens到词表
for sp_token in special_tokens:
    if len(vocab) >= vocab_size:
        break
    sp_token_bytes = sp_token.encode('utf-8')
    if sp_token_bytes not in existing_bytes_token:
        vocab[next_token_id] = sp_token_bytes
        existing_bytes_token.add(sp_token_bytes)
        next_token_id += 1

print(f"vocab: {vocab}")
print(f"existing_bytes_token: {existing_bytes_token}")
print(f"vocab_size: {len(vocab)}")
# Out:
# vocab: {0: b'\x00', 1: b'\x01', 2: b'\x02', 3: b'\x03', 4: b'\x04', 5: b'\x05', 6: b'\x06', 7: b'\x07', 8: b'\x08', 9: b'\t', 10: b'\n', 11: b'\x0b', 12: b'\x0c', 13: b'\r', 14: b'\x0e', 15: b'\x0f', 16: b'\x10', 17: b'\x11', 18: b'\x12', 19: b'\x13', 20: b'\x14', 21: b'\x15', 22: b'\x16', 23: b'\x17', 24: b'\x18', 25: b'\x19', 26: b'\x1a', 27: b'\x1b', 28: b'\x1c', 29: b'\x1d', 30: b'\x1e', 31: b'\x1f', 32: b' ', 33: b'!', 34: b'"', 35: b'#', 36: b'$', 37: b'%', 38: b'&', 39: b"'", 40: b'(', 41: b')', 42: b'*', 43: b'+', 44: b',', 45: b'-', 46: b'.', 47: b'/', 48: b'0', 49: b'1', 50: b'2', 51: b'3', 52: b'4', 53: b'5', 54: b'6', 55: b'7', 56: b'8', 57: b'9', 58: b':', 59: b';', 60: b'<', 61: b'=', 62: b'>', 63: b'?', 64: b'@', 65: b'A', 66: b'B', 67: b'C', 68: b'D', 69: b'E', 70: b'F', 71: b'G', 72: b'H', 73: b'I', 74: b'J', 75: b'K', 76: b'L', 77: b'M', 78: b'N', 79: b'O', 80: b'P', 81: b'Q', 82: b'R', 83: b'S', 84: b'T', 85: b'U', 86: b'V', 87: b'W', 88: b'X', 89: b'Y', 90: b'Z', 91: b'[', 92: b'\\', 93: b']', 94: b'^', 95: b'_', 96: b'`', 97: b'a', 98: b'b', 99: b'c', 100: b'd', 101: b'e', 102: b'f', 103: b'g', 104: b'h', 105: b'i', 106: b'j', 107: b'k', 108: b'l', 109: b'm', 110: b'n', 111: b'o', 112: b'p', 113: b'q', 114: b'r', 115: b's', 116: b't', 117: b'u', 118: b'v', 119: b'w', 120: b'x', 121: b'y', 122: b'z', 123: b'{', 124: b'|', 125: b'}', 126: b'~', 127: b'\x7f', 128: b'\x80', 129: b'\x81', 130: b'\x82', 131: b'\x83', 132: b'\x84', 133: b'\x85', 134: b'\x86', 135: b'\x87', 136: b'\x88', 137: b'\x89', 138: b'\x8a', 139: b'\x8b', 140: b'\x
b'\x9a', b'\xfd', b'%', b'R', b'g', b'\xf7', b'\xca', b'E', b'\x0b', b'\xd6', b'\xea', b'8', b'\x85', b'\x87', b'1', b'\xa3', b'\xda', b'e', b' ', b'\\', b'\xba', b'\xec', b'\xe5', b'\x86', b'<', b'<|startoftext|>', b'\xc7', b'\x1e', b'\x1c', b'\x90', b'\xa7', b'\xbb', b'\x89', b'/', b'M', b'\x93', b'\x10', b'\xe0', b'\xbf', b'\xf1', b'S', b'\xed', b'\xf5', b'\x02', b'\x1b', b'"', b'\xee', b'\x12', b'\x81', b'\xf2', b'\xcd', b'$', b'\xb3', b'6', b'\xb1', b'\xf0', b'\xf3', b'\xb7', b'\xe7', b'\xfc', b'\x8a', b'\xad', b'\x16', b'[', b'\x98', b'\x07', b'y', b'\xd5', b'O', b'_', b'\xc4', b'\xdb', b'\xbe', b'\x06', b'\x9b', b'\xb8', b'G', b'i', b'7', b',', b'K', b'\x18', b'V', b'\t', b'l', b'\xb4', b'Z', b'f', b'x', b'\xa4', b'\xc8', b'\xcf', b'\xeb', b'{', b'\x0c', b'\xc3', b'\xd8', b'\xe8', b'}', b'\xd2', b'\xfb', b'|', b';', b'\x9e', b'\xab', b'\xd3', b'\xde', b'`', b'\x82', b'\x8f', b'\xc9', b'F', b'\xe1', b'<|endoftext|>', b'\x03', b'\xc6', b'n', b'\x13', b'\x94', b'\x99', b'\n', b'a', b']', b'\xb0', b'\x7f', b'\x83', b'\xd9', b'2', b'\xe2', b'\x05', b'\xdd', b'c', b'C', b'=', b'\xcc', b'H', b'Q', b'h', b'~', b'\xaa', b'\xb9', b'\xce', b'\x17', b'\x92', b'\xae', b't', b'\xc1', b'm', b'p', b'\xb5', b'\xc2', b'\xd1', b'\xac', b'#', b'(', b'v', b'\xc5', b'\x0e', b':', b'\x1f', b'q', b'\xc0', b'\x00', b'\xe9', b'\x08', b'-', b'5', b'&', b'\xbd', b'\xb6', b'>', b'\xa0', b'0', b'\x0f', b'X', b'\r', b'.', b'T', b'\x95', b'L', b'\xa6', b'@', b'\x97', b'\x9d', b'j', b'\xf8', b'9', b'\x8c', b'P', b'+', b"'", b'\xbc'}
# vocab_size: 258

# %%
from collections import Counter
# 2.pre-tokenization
num_processes = 8  # Number of processes to use for parallelization
with open(input_path, 'rb') as f:
    boundaries:list[int] = find_chunk_boundaries(
        f, num_processes, "<|endoftext|>".encode("utf-8"))
    # 切分文件为多个部分
    print(f"Chunk boundaries: {boundaries}")

    for start, end in zip(boundaries[:-1], boundaries[1:]):
        f.seek(start)
        # 以字节形式读取，解码为字符串
        chunk:str = f.read(end - start).decode("utf-8", errors="ignore")
        print(f"Processing chunk from {start} to {end}, length: {len(chunk)}")
        print(f"Chunk content: {chunk[:100]}...")  
        # 删除特殊token
        split_pattern:str = "|".join([re.escape(special_token) for special_token in set(special_tokens)])
        # 将chunk按特殊token进行分割
        if not split_pattern:
            chunk_no_special_token:list[str] = [chunk]
        else:
            chunk_no_special_token:list[str] = re.split(split_pattern, chunk)
        # 对每个chunk进行预分词
        PAT = r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""
        pre_token_counter:Counter[tuple[bytes,...]] = Counter() # 预分词频率表
        for sub_chunk in chunk_no_special_token:
            if not sub_chunk or sub_chunk.isspace():
                continue
# 预分词后应得到频率表dict[tuple[bytes],int]
            for match in re.finditer(PAT, sub_chunk):
                pre_token:bytes = match.group(0).encode('utf-8')
                pre_token_bytes = tuple(bytes([b]) for b in pre_token)  
                # print(pre_token_bytes)
                pre_token_counter[pre_token_bytes] += 1
           
    print(pre_token_counter)
# Out:
# Chunk boundaries: [0, 2813541, 5625758, 8438541, 11252559, 14064356, 16877372, 19690315, 22502601]
# Processing chunk from 0 to 2813541, length: 2812473
# Chunk content: u don't have to be scared of the loud dog, I'll protect you". The mole felt so safe with the little ...
# Processing chunk from 2813541 to 5625758, length: 2810964
# Chunk content: <|endoftext|>
#
# Tommy was excited that it was time to play with his new toy car. He ran down the stai...
# Processing chunk from 5625758 to 8438541, length: 2811507
# Chunk content: <|endoftext|>
# Once upon a time, in a green forest, there lived a big bear and a little bunny. They w...
# Processing chunk from 8438541 to 11252559, length: 2812828
# Chunk content: <|endoftext|>
#
# Once there was a young girl called Lucy. She was only three years old and loved playi...
# Processing chunk from 11252559 to 14064356, length: 2810919
# Chunk content: <|endoftext|>
# Once upon a time, there was a little boy named Tim. Tim loved to print pictures of ani...
# Processing chunk from 14064356 to 16877372, length: 2811778
# Chunk content: <|endoftext|>
# Once upon a time, there was a little goat. The goat lived in a hidden place in the woo...
# Processing chunk from 16877372 to 19690315, length: 2811692
# Chunk content: <|endoftext|>
# Once upon a time, there was a big purple cat named Tom. Tom lived in a little house wi...
# Processing chunk from 19690315 to 22502601, length: 2811226
# Chunk content: <|endoftext|>
# One day, a bald man named Tom went for a walk. He saw a little girl named Sally. Sally...
# Counter({(b'.',): 52493, (b',',): 29297, (b' ', b't', b'h', b'e'): 26572, (b' ', b'a', b'n', b'd'): 25009, (b'\n',): 19105, (b' ', b'a'): 18887, (b' ', b't', b'o'): 18845, (b' ', b'w', b'a', b's'): 13194, (b' ', b'T', b'h', b'e', b'y'): 6878, (b' ', b'i', b't'): 6451, (b' ', b'"'): 5886, (b' ', b'H', b'e'): 5885, (b' ', b'T', b'h', b'e'): 5779, (b' ', b's', b'a', b'i', b'd'): 5414, (b' ', b'd', b'a', b'y'): 5358, (b' ', b'w', b'i', b't', b'h'): 5325, (b' ', b'i', b'n'): 4886, (b' ', b'h', b'e', b'r'): 4876, (b' ', b'S', b'h', b'e'): 4804, (b' ', b'h', b'i', b's'): 4794, (b' ', b'T', b'i', b'm'): 4420, (b' ', b'b', b'i', b'g'): 4321, (b' ', b'h', b'e'): 3951, (b' ', b't', b'h', b'e', b'y'): 3885, (b' ', b'h', b'a', b'd'): 3627, (b' ', b'y', b'o', b'u'): 3548, (b' ', b'o', b'f'): 3251, (b' ', b'n', b'o', b't'): 3234, (b' ', b'o', b'n'): 3231, (b' ',
b'k', b'e'): 1157, (b' ', b't', b'o', b'y'): 1155, (b' ', b'M', b'a', b'x'): 1154, (b' ', b'b', b'a', b'l', b'l'): 1143, (b' ', b'w', b'o', b'u', b'l', b'd'): 1138, (b' ', b'B', b'u', b't'): 1090, (b' ', b'O', b'n', b'e'): 1088, (b' ', b'f', b'e', b'l', b't'): 1086, (b' ', b'n', b'e', b'w'): 1081, (b' ', b'l', b'i', b'k', b'e', b'd'): 1071, (b'I',): 1053, (b' ', b'a', b's', b'k', b'e', b'd'): 1049, (b' ', b'c', b'a', b'm', b'e'): 1039, (b' ', b'm', b'a', b'k', b'e'): 1029, (b' ', b's', b't', b'a', b'r', b't', b'e', b'd'): 1016, (b' ', b'S', b'a', b'm'): 985, (b' ', b'B', b'e', b'n'): 971, (b' ', b's', b'm', b'i', b'l', b'e', b'd'): 968, (b' ', b's', b'e', b'e'): 961, (b' ', b'w', b'a', b'n', b't'): 957, (b' ', b'w', b'h', b'a', b't'): 956, (b' ', b's', b'm', b'a', b'l', b'l'): 955, (b' ', b'f', b'r', b'o', b'm'): 914, (b' ', b'h', b'o', b'm ...

# %%
from cs336_basics.train_bpe import merge,get_stat,train_bpe,pre_tokenization
pre_token_counter = pre_tokenization(input_path, special_tokens)
# Out:
# 6765
# Pre-token: b'\n', Count: 19105
# Pre-token: b'One', Count: 2009
# Pre-token: b' day', Count: 5358
# Pre-token: b',', Count: 29297
# Pre-token: b' a', Count: 18887
# Pre-token: b' bald', Count: 13
# Pre-token: b' man', Count: 711
# Pre-token: b' named', Count: 2528
# Pre-token: b' Tom', Count: 2134

# %%
vocab,merges = train_bpe(input_path, vocab_size=vocab_size, special_tokens=special_tokens)
print(f"vocab: {vocab}")
print(f"merges: {merges}")
# Out:
# ---------------------------------------------------------------------------
# PatternError                              Traceback (most recent call last)
# Cell In[41], line 2
#       1 from cs336_basics.train_bpe import merge,get_stat,train_bpe
# ----> 2 vocab,merges = train_bpe(input_path, vocab_size=vocab_size, special_tokens=special_tokens)
#       3 print(f"vocab: {vocab}")
#       4 print(f"merges: {merges}")
#
# File <string>:27, in train_bpe(input_path, vocab_size, special_tokens)
#
# File <string>:26, in pre_tokenization(input_path, special_tokens, num_processes)
#
# File ~/.local/share/uv/python/cpython-3.13.3-linux-x86_64-gnu/lib/python3.13/re/__init__.py:285, in finditer(pattern, string, flags)
#     280 def finditer(pattern, string, flags=0):
#     281     """Return an iterator over all non-overlapping matches in the
#     282     string.  For each match, the iterator returns a Match object.
#     283
#     284     Empty matches are included in the result."""
# --> 285     return _compile(pattern, flags).finditer(string)
#
# File ~/.local/share/uv/python/cpython-3.13.3-linux-x86_64-gnu/lib/python3.13/re/__init__.py:350, in _compile(pattern, flags)
#     348 if not _compiler.isstring(pattern):
#     349     raise TypeError("first argument must be string or compiled pattern")
# --> 350 p = _compiler.compile(pattern, flags)
#     351 if flags & DEBUG:
#     352     return p
#
# File ~/.local/share/uv/python/cpython-3.13.3-linux-x86_64-gnu/lib/python3.13/re/_compiler.py:748, in compile(p, flags)
#     746 if isstring(p):
#     747     pattern = p
# --> 748     p = _parser.parse(p, flags)
#     749 else:
#     750     pattern = None
#
# File ~/.local/share/uv/python/cpython-3.13.3-linux-x86_64-gnu/lib/python3.13/re/_parser.py:980, in parse(str, flags, state)
#     977 state.flags = flags
#     978 state.str = str
# --> 980 p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     981 p.state.flags = fix_flags(str, p.state.flags)
#     983 if source.next is not None:
#
# File ~/.local/share/uv/python/cpython-3.13.3-linux-x86_64-gnu/lib/python3.13/re/_parser.py:459, in _parse_sub(source, state, verbose, nested)
#     457 start = source.tell()
#     458 while True:
# --> 459     itemsappend(_parse(source, state, verbose, nested + 1,
#     460                        not nested and not items))
#     461     if not sourcematch("|"):
#     462         break
#
# File ~/.local/share/uv/python/cpython-3.13.3-linux-x86_64-gnu/lib/python3.13/re/_parser.py:543, in _parse(source, state, verbose, nested, first)
#     540         continue
#     542 if this[0] == "\\":
# --> 543     code = _escape(source, this, state)
#     544     subpatternappend(code)
#     546 elif this not in SPECIAL_CHARS:
#
# File ~/.local/share/uv/python/cpython-3.13.3-linux-x86_64-gnu/lib/python3.13/re/_parser.py:442, in _escape(source, escape, state)
#     440     if len(escape) == 2:
#     441         if c in ASCIILETTERS:
# --> 442             raise source.error("bad escape %s" % escape, len(escape))
#     443         return LITERAL, ord(escape[1])
#     444 except ValueError:
#
# PatternError: bad escape \p at position 23

# %%
# 3.迭代合并字节对
while len(vocab) < 300:
    # 找到频率最高的字节对
    most_common_pair = get_stat(pre_token_counter,existing_bytes_token)
    if not most_common_pair:
        break
    b0, b1 = most_common_pair
    merge_token = b0 + b1
    # 如果合并后的token已经存在于词表中，则只需清除pre-token中的单个token跳过
    if merge_token in existing_bytes_token:
        pre_token_counter.pop(merge_token, None)
        continue
    # 将合并后的token添加到词表
    vocab[next_token_id] = merge_token
    existing_bytes_token.add(merge_token)
    merges.append((b0, b1))
    next_token_id += 1
    # 更新pre-token计数器
    print(len(vocab))
    print(merge_token)
    pre_token_counter:Counter[bytes] = merge(pre_token_counter, b0, b1, merge_token)
print(f"vocab {vocab}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 5
#       2 # 3.迭代合并字节对
#       3 while len(vocab) < 300:
#       4     # 找到频率最高的字节对
# ----> 5     most_common_pair = get_stat(pre_token_counter,existing_bytes_token)
#       6     if not most_common_pair:
#       7         break
#
# File ~/cs-learning/python-project/deeplearning/cs336-2025spring/assignment1-basics/cs336_basics/train_bpe.py:124, in get_stat(pre_token_counter, existing_bytes_token)
#     122         continue
#     123     for b0,b1 in zip(pre_token[:-1], pre_token[1:]):
# --> 124         pair_counter[(bytes([b0]), bytes([b1]))] += count
#     125 # 获取出现频率最高的字节对
#     126 most_common_pair = pair_counter.most_common(1)[0][0]
#
# KeyboardInterrupt:

# %%
# Out:
# ---------------------------------------------------------------------------
# PatternError                              Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 vocab, merges = train_bpe(input_path=input_path,
#       2                           vocab_size=vocab_size,
#       3                           special_tokens=special_tokens,)
#       4 print(f"vocab:{ vocab}")
#       5 print(f"merges: {merges}")
#
# File ~/cs-learning/python-project/deeplearning/cs336-2025spring/assignment1-basics/cs336_basics/train_bpe.py:39, in train_bpe(input_path, vocab_size, special_tokens)
#      36         next_token_id += 1
#      38 # 2.pre-tokenization
# ---> 39 pre_token_counter:Counter[bytes] = pre_tokenization(input_path, special_tokens)
#      40 # 3.迭代合并字节对
#      41 while len(vocab) < vocab_size:
#      42     # 找到频率最高的字节对
#
# File ~/cs-learning/python-project/deeplearning/cs336-2025spring/assignment1-basics/cs336_basics/train_bpe.py:98, in pre_tokenization(input_path, special_tokens, num_processes)
#      96 if not sub_chunk or sub_chunk.isspace():
#      97     continue
# ---> 98 for match in re.finditer(PAT, sub_chunk):
#      99     pre_token:bytes = match.group(0).encode('utf-8')
#     100     pre_token_counter[pre_token] += 1
#
# File ~/.local/share/uv/python/cpython-3.13.3-linux-x86_64-gnu/lib/python3.13/re/__init__.py:285, in finditer(pattern, string, flags)
#     280 def finditer(pattern, string, flags=0):
#     281     """Return an iterator over all non-overlapping matches in the
#     282     string.  For each match, the iterator returns a Match object.
#     283
#     284     Empty matches are included in the result."""
# --> 285     return _compile(pattern, flags).finditer(string)
#
# File ~/.local/share/uv/python/cpython-3.13.3-linux-x86_64-gnu/lib/python3.13/re/__init__.py:350, in _compile(pattern, flags)
#     348 if not _compiler.isstring(pattern):
#     349     raise TypeError("first argument must be string or compiled pattern")
# --> 350 p = _compiler.compile(pattern, flags)
#     351 if flags & DEBUG:
#     352     return p
#
# File ~/.local/share/uv/python/cpython-3.13.3-linux-x86_64-gnu/lib/python3.13/re/_compiler.py:748, in compile(p, flags)
#     746 if isstring(p):
#     747     pattern = p
# --> 748     p = _parser.parse(p, flags)
#     749 else:
#     750     pattern = None
#
# File ~/.local/share/uv/python/cpython-3.13.3-linux-x86_64-gnu/lib/python3.13/re/_parser.py:980, in parse(str, flags, state)
#     977 state.flags = flags
#     978 state.str = str
# --> 980 p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     981 p.state.flags = fix_flags(str, p.state.flags)
#     983 if source.next is not None:
#
# File ~/.local/share/uv/python/cpython-3.13.3-linux-x86_64-gnu/lib/python3.13/re/_parser.py:459, in _parse_sub(source, state, verbose, nested)
#     457 start = source.tell()
#     458 while True:
# --> 459     itemsappend(_parse(source, state, verbose, nested + 1,
#     460                        not nested and not items))
#     461     if not sourcematch("|"):
#     462         break
#
# File ~/.local/share/uv/python/cpython-3.13.3-linux-x86_64-gnu/lib/python3.13/re/_parser.py:543, in _parse(source, state, verbose, nested, first)
#     540         continue
#     542 if this[0] == "\\":
# --> 543     code = _escape(source, this, state)
#     544     subpatternappend(code)
#     546 elif this not in SPECIAL_CHARS:
#
# File ~/.local/share/uv/python/cpython-3.13.3-linux-x86_64-gnu/lib/python3.13/re/_parser.py:442, in _escape(source, escape, state)
#     440     if len(escape) == 2:
#     441         if c in ASCIILETTERS:
# --> 442             raise source.error("bad escape %s" % escape, len(escape))
#     443         return LITERAL, ord(escape[1])
#     444 except ValueError:
#
# PatternError: bad escape \p at position 23
